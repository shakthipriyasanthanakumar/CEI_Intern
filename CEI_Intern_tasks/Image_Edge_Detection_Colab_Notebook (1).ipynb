# %% [markdown]
# # 🧠 Edge Detection using OpenCV
# This notebook allows you to upload an image and apply edge detection using OpenCV.

# %%
# Install required package
# !pip install opencv-python-headless

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from PIL import Image
import io

# %%
# Upload your image
uploaded = files.upload()
image_path = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-0ef5852a-3054-4cab-bd9c-e97210a1c3ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ef5852a-3054-4cab-bd9c-e97210a1c3ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read and process the image
image = Image.open(image_path).convert('RGB')
image_np = np.array(image)

# Convert to grayscale
gray = cv2.cvtColor(image_np, cv2.COLOR_RGB2GRAY)

# Apply Canny Edge Detection
edges = cv2.Canny(gray, 100, 200)

# %%
# Plot results
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(image_np)
axs[0].set_title('Original Image')
axs[0].axis('off')

axs[1].imshow(gray, cmap='gray')
axs[1].set_title('Grayscale Image')
axs[1].axis('off')

axs[2].imshow(edges, cmap='gray')
axs[2].set_title('Canny Edge Detection')
axs[2].axis('off')

plt.tight_layout()
plt.show()

# %%
# 📌 Install OpenCV if not already
# !pip install opencv-python-headless

# 📌 Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from PIL import Image
import io

# 📌 Upload an image
uploaded = files.upload()
image_path = list(uploaded.keys())[0]

# 📌 Load and prepare image
image = Image.open(image_path).convert('RGB')
image_np = np.array(image)

# Step 1: Convert to grayscale
gray = cv2.cvtColor(image_np, cv2.COLOR_RGB2GRAY)

# Step 2: Median blur
gray_blur = cv2.medianBlur(gray, 7)

# Step 3: Detect edges
edges = cv2.adaptiveThreshold(
    gray_blur, 255,
    cv2.ADAPTIVE_THRESH_MEAN_C,
    cv2.THRESH_BINARY,
    blockSize=9, C=2
)

# Step 4: Smooth color using bilateral filter
color = cv2.bilateralFilter(image_np, d=9, sigmaColor=300, sigmaSpace=300)

# Step 5: Combine edges and color
cartoon = cv2.bitwise_and(color, color, mask=edges)

# 📌 Show all stages
fig, axs = plt.subplots(1, 3, figsize=(18, 6))
axs[0].imshow(image_np)
axs[0].set_title('Original Image')
axs[0].axis('off')

axs[1].imshow(edges, cmap='gray')
axs[1].set_title('Edge Detection')
axs[1].axis('off')

axs[2].imshow(cartoon)
axs[2].set_title('Cartoonified Image')
axs[2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# ...
#      <input type="file" id="files-bcd8bb20-603f-439d-9cbd-3362f8acff23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bcd8bb20-603f-439d-9cbd-3362f8acff23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
